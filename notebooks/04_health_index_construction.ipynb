# %% [markdown]
# # 04 Health Index Construction
#
# ## Purpose
# Construct Health Index (HI) signals and evaluate HI quality for maintenance decision support.
#
# ## Outputs
# - HI trajectories by unit
# - HI quality metrics (monotonicity, smoothness, correlation)
# - Threshold-oriented decision analysis artifacts
#
# ## Assumptions
# - HI is derived from available sensors without future leakage
# - Evaluation is aligned with reliability-focused interpretation
# - All reusable logic is promoted to src/ modules

# %%
# Notebook workspace
