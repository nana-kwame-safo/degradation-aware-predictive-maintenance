# %% [markdown]
# # 01 Exploratory Data Analysis
#
# ## Purpose
# Inspect CMAPSS FD001 data quality, trajectory behavior, and sensor signal characteristics before modeling.
#
# ## Outputs
# - Dataset shape and per-unit summary statistics
# - Cycle trajectory and sensor profile visual checks
# - Initial list of sensors/issues for preprocessing
#
# ## Assumptions
# - Raw files are available under data/raw/cmapss
# - No labels are altered in this notebook
# - Findings will be transferred to src/ for reproducible pipeline logic
