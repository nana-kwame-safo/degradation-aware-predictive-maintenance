# %% [markdown]
# # 05 Sequence Models
#
# ## Purpose
# Evaluate sequence models (e.g., LSTM/TCN) as controlled extensions to baseline methods.
#
# ## Outputs
# - Sequence model training/evaluation summaries
# - Comparison against interpretable baselines
# - Documented stability/generalization observations
#
# ## Assumptions
# - Baseline pipeline and metrics are already established
# - Windowed inputs use unit-safe boundaries
# - Model changes are tracked with reproducible configs

# %%
# Notebook workspace
